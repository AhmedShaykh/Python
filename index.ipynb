# %%
print("Learning Python");
# Out:
# Learning Python

# %%
value = "Working In MYPY";

print(type(value));
print(id(value));
print(value);
# Out:
# <class 'str'>
# 140383169655216
# Working In MYPY

# %%
name = "my name is ahmed shaykh";

print(name.title());
# Out:
# My Name Is Ahmed Shaykh

# %%
num1: int = 7;

print(num1);
# Out:
# 7

# %%
num = 4;

print(type(num));
print(num);

num: float = 4.4;

print(type(num));
print(num);
# Out:
# <class 'int'>
# 4
# <class 'float'>
# 4.4

# %%
data: bool = 0;

print(type(data));
print(data);

data: str = "Amsterdam";

print(type(data));
print(data);
# Out:
# <class 'int'>
# 0
# <class 'str'>
# Amsterdam

# %%
from typing import List;

lists: List[int] = [1,2,3];

print(type(lists));
print(lists);
# Out:
# <class 'list'>
# [1, 2, 3]

# %%
setType: set[int] = {1,2,3};

print(type(setType));
print(setType);
# Out:
# <class 'set'>
# {1, 2, 3}

# %%
tuples: tuple[int] = (1,2,3,4);

print(type(tuples));
print(tuples);
# Out:
# <class 'tuple'>
# (1, 2, 3, 4)

# %%
from typing import Dict;

dictType: Dict[str, str] = {
    "name": "AHMX",
    "age": "23"
};

print(type(dictType));
print(dictType);
# Out:
# <class 'dict'>
# {'name': 'AHMX', 'age': '23'}

# %%
a: str = "PaKiSTaN";

print(a.title());
# Out:
# Pakistan

# %%
age: int = 23;

name: str = "Ahmed";

data: str = name + " " + str(age);

print(data);
# Out:
# Ahmed 23

# %%
age: int = 23;

name: str = "Ahmed";

data: str = f"""
{name} age is {age}
""";

print(data);
# Out:
# Ahmed age is 23

# %%
age: int = 23;

child: bool;

if age < 18:
    child = True;
else:
    child = False;

print(child);
# Out:
# False

# %%
print("Languages:\n\tPython\n\tJavaScript\n\tTypeScript");
# Out:
# Languages:
# 	Python
# 	JavaScript
# 	TypeScript
